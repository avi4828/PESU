# %% [markdown]
# CSV

# %%
import csv

# %% [markdown]
# csv reader() function

# %%
# reader function was use to read a data form csv file 
# reader function was get 1 arrgument is open file 
# reader function was give a list of list data
with open('file1.csv','r') as f:
    rd = csv.reader(f)
    for r in rd:
        print(r)
# Out:
# ['Name', 'Age', 'Perfession']
# ['a', '22', 'doctor']
# ['b', '23', 'Engnieer']
# ['c', '22', 'doctor']
